# %%
import torch
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torchvision.utils import save_image
from torch.utils.data import DataLoader as DataLoader
import torch.nn as nn
import torch.optim as opt
from torch.autograd import Variable

import numpy as np
import matplotlib.pyplot as plt

# %%
def to_var(x):
  if torch.cuda.is_available():
    x = x.cuda()
  return Variable(x)

# %%
# 超參數
num_epoch = 200
learning_rate = 0.0005

# %%
# define tansform
transform = transforms.Compose([
  transforms.ToTensor(),
  transforms.Normalize(mean=0.5, std=0.5) # std 標準差
]) # Compose input type: list

# %%
train_dataset = dsets.MNIST(root='./data', train=True, transform=transform, download=True)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# %%
D = nn.Sequential(
    nn.Linear(28*28, 256), #input為圖片
    nn.LeakyReLU(0.2),
    nn.Linear(256, 256),
    nn.LeakyReLU(0.2),
    nn.Linear(256, 1),
    nn.Sigmoid()
)

# %%
G = nn.Sequential(
    nn.Linear(64, 256), #input custormizer 64 here
    nn.LeakyReLU(0.2),
    nn.Linear(256, 256),
    nn.LeakyReLU(0.2),
    nn.Linear(256, 28*28),
    nn.Tanh() # 因為transform的時候有Normalize在+-1間(mean=0.5)
)

# %%
# GPU
if torch.cuda.is_available():
  D.cuda()
  G.cuda()

# %%
loss_func = nn.BCELoss() # binary cross entropy
d_opt = opt.Adam(D.parameters(), lr=learning_rate)
g_opt = opt.Adam(G.parameters(), lr=learning_rate)

# %%
def de_normalize(x):
  out = (x + 1)/2
  return out.clamp(0, 1) # 所有小於0的都等於0, 所有大於1的都等於1

# %%
for epoch in range(num_epoch):
  for i, (images, _) in enumerate(train_loader):
    batch_size = images.size(0) # images.size(0) 總共多少資料
    images = to_var(images)
    images = images.view(batch_size, -1)

    # 真實圖片的 LABEL 都為1
    real_labels = to_var(torch.ones(batch_size, 1)) # (row, col)
    # 假圖片的 LABEL 都為0
    fake_labels = to_var(torch.zeros(batch_size, 1)) # (row, col)

    outputs = D(images)
    d_loss_at_real = loss_func(outputs, real_labels)
    real_score = outputs

    z = to_var(torch.randn(batch_size, 64)) # 要餵給G的隨機產生的向量, 64為G的輸入向量
    fake_images = G(z) 
    outputs = D(fake_images) # or output = D(G(z))
    
    d_loss_at_fake = loss_func(outputs, fake_labels) # output和0的距離
    fake_score = outputs # fake 越高表示G騙過D

    d_loss = d_loss_at_real + d_loss_at_fake
    D.zero_grad()
    d_loss.backward()
    d_opt.step()

    # 需要重新產生fake image
    z = to_var(torch.randn(batch_size, 64)) # 要餵給G的隨機產生的向量, 64為G的輸入向量
    fake_images = G(z) 
    outputs = D(fake_images) # or output = D(G(z))

    g_loss = loss_func(outputs, real_labels) # output和1的距離
    D.zero_grad() # because D(G(z))
    G.zero_grad()
    g_loss.backward()
    g_opt.step()

    if (i+1)%300 == 0:
      print('Epoch[%d], Batch[%d], d_loss:%.4f, g_loss:%.4f, D(x): %.2f, D(G(x)): %.2f'%(epoch+1, i+1, d_loss.data, g_loss.data, real_score.mean(), fake_score.mean()))
  
  if (epoch == 0): # 第一次先存正常的圖
    images = images.view(images.size(0), 1, 28, 28)
    save_image(de_normalize(images.data), './data/real_images.png')

  fake_images = fake_images.view(fake_images.size(0), 1, 28, 28)
  save_image(de_normalize(fake_images.data), './data/fake_images_'+str(epoch+1)+'.png')
# Out:
# Epoch[1], Batch[300], d_loss:0.3041, g_loss:2.7757, D(x): 0.88, D(G(x)): 0.15
# Epoch[1], Batch[600], d_loss:0.5936, g_loss:6.7802, D(x): 0.89, D(G(x)): 0.21
# Epoch[2], Batch[300], d_loss:0.3842, g_loss:5.9143, D(x): 0.88, D(G(x)): 0.13
# Epoch[2], Batch[600], d_loss:5.2407, g_loss:18.5732, D(x): 0.86, D(G(x)): 0.19
# Epoch[3], Batch[300], d_loss:1.3538, g_loss:8.2342, D(x): 0.73, D(G(x)): 0.24
# Epoch[3], Batch[600], d_loss:0.7886, g_loss:1.7929, D(x): 0.76, D(G(x)): 0.32
# Epoch[4], Batch[300], d_loss:0.7515, g_loss:23.8499, D(x): 0.86, D(G(x)): 0.08
# Epoch[4], Batch[600], d_loss:0.4190, g_loss:5.0527, D(x): 0.82, D(G(x)): 0.11
# Epoch[5], Batch[300], d_loss:1.2832, g_loss:3.6098, D(x): 0.67, D(G(x)): 0.25
# Epoch[5], Batch[600], d_loss:0.9079, g_loss:3.5050, D(x): 0.69, D(G(x)): 0.14
# Epoch[6], Batch[300], d_loss:0.4775, g_loss:3.2977, D(x): 0.85, D(G(x)): 0.17
# Epoch[6], Batch[600], d_loss:1.2422, g_loss:2.5830, D(x): 0.77, D(G(x)): 0.37
# Epoch[7], Batch[300], d_loss:0.7057, g_loss:2.4286, D(x): 0.79, D(G(x)): 0.24
# Epoch[7], Batch[600], d_loss:0.6449, g_loss:5.5200, D(x): 0.92, D(G(x)): 0.23
# Epoch[8], Batch[300], d_loss:0.9599, g_loss:5.2363, D(x): 0.74, D(G(x)): 0.13
# Epoch[8], Batch[600], d_loss:1.1917, g_loss:2.4325, D(x): 0.73, D(G(x)): 0.36
# Epoch[9], Batch[300], d_loss:1.9505, g_loss:4.3243, D(x): 0.52, D(G(x)): 0.18
# Epoch[9], Batch[600], d_loss:1.0587, g_loss:1.8024, D(x): 0.65, D(G(x)): 0.26
# Epoch[10], Batch[300], d_loss:0.8644, g_loss:2.2377, D(x): 0.81, D(G(x)): 0.35
# Epoch[10], Batch[600], d_loss:1.5380, g_loss:1.3078, D(x): 0.66, D(G(x)): 0.53
# Epoch[11], Batch[300], d_loss:1.1571, g_loss:1.9293, D(x): 0.65, D(G(x)): 0.36
# Epoch[11], Batch[600], d_loss:1.2302, g_loss:1.6269, D(x): 0.58, D(G(x)): 0.33
# Epoch[12], Batch[300], d_loss:1.2678, g_loss:3.0120, D(x): 0.74, D(G(x)): 0.39
# Epoch[12], Batch[600], d_loss:1.6796, g_loss:1.2810, D(x): 0.56, D(G(x)): 0.42
# Epoch[13], Batch[300], d_loss:1.1349, g_loss:2.7075, D(x): 0.84, D(G(x)): 0.48
# Epoch[13], Batch[600], d_loss:0.9484, g_loss:1.5913, D(x): 0.65, D(G(x)): 0.26
# Epoch[14], Batch[300], d_loss:1.0099, g_loss:1.7646, D(x): 0.79, D(G(x)): 0.43
# Epoch[14], Batch[600], d_loss:0.3931, g_loss:3.2437, D(x): 0.79, D(G(x)): 0.10
# Epoch[15], Batch[300], d_loss:1.1910, g_loss:1.5284, D(x): 0.58, D(G(x)): 0.21
# Epoch[15], Batch[600], d_loss:1.0518, g_loss:2.0344, D(x): 0.77, D(G(x)): 0.33
# Epoch[16], Batch[300], d_loss:0.7037, g_loss:2.1868, D(x): 0.84, D(G(x)): 0.27
# Epoch[16], Batch[600], d_loss:0.4999, g_loss:2.9007, D(x): 0.89, D(G(x)): 0.25
# Epoch[17], Batch[300], d_loss:1.2749, g_loss:1.5638, D(x): 0.68, D(G(x)): 0.41
# Epoch[17], Batch[600], d_loss:0.8527, g_loss:2.1304, D(x): 0.71, D(G(x)): 0.28
# Epoch[18], Batch[300], d_loss:0.6818, g_loss:2.4989, D(x): 0.83, D(G(x)): 0.26
# Epoch[18], Batch[600], d_loss:0.5815, g_loss:3.4670, D(x): 0.79, D(G(x)): 0.17
# Epoch[19], Batch[300], d_loss:0.7158, g_loss:2.4603, D(x): 0.81, D(G(x)): 0.28
# Epoch[19], Batch[600], d_loss:1.0433, g_loss:2.6372, D(x): 0.69, D(G(x)): 0.29
# Epoch[20], Batch[300], d_loss:0.6794, g_loss:1.6816, D(x): 0.75, D(G(x)): 0.22
# Epoch[20], Batch[600], d_loss:1.2516, g_loss:1.9907, D(x): 0.68, D(G(x)): 0.33
# Epoch[21], Batch[300], d_loss:0.7347, g_loss:2.4487, D(x): 0.77, D(G(x)): 0.20
# Epoch[21], Batch[600], d_loss:1.3481, g_loss:1.9771, D(x): 0.78, D(G(x)): 0.43
# Epoch[22], Batch[300], d_loss:0.7235, g_loss:2.6885, D(x): 0.76, D(G(x)): 0.21
# Epoch[22], Batch[600], d_loss:0.7735, g_loss:1.7444, D(x): 0.75, D(G(x)): 0.27
# Epoch[23], Batch[300], d_loss:0.4295, g_loss:3.1682, D(x): 0.84, D(G(x)): 0.12
# Epoch[23], Batch[600], d_loss:1.0636, g_loss:2.8458, D(x): 0.81, D(G(x)): 0.28
# Epoch[24], Batch[300], d_loss:1.0231, g_loss:3.6144, D(x): 0.68, D(G(x)): 0.18
# Epoch[24], Batch[600], d_loss:0.7336, g_loss:1.8180, D(x): 0.71, D(G(x)): 0.20
# Epoch[25], Batch[300], d_loss:0.8551, g_loss:2.3917, D(x): 0.79, D(G(x)): 0.31
# Epoch[25], Batch[600], d_loss:0.9476, g_loss:2.5403, D(x): 0.67, D(G(x)): 0.21
# Epoch[26], Batch[300], d_loss:1.0429, g_loss:1.9236, D(x): 0.78, D(G(x)): 0.38
# Epoch[26], Batch[600], d_loss:1.1807, g_loss:1.7904, D(x): 0.68, D(G(x)): 0.36
# Epoch[27], Batch[300], d_loss:1.0154, g_loss:1.9935, D(x): 0.64, D(G(x)): 0.31
# Epoch[27], Batch[600], d_loss:0.8223, g_loss:2.3739, D(x): 0.75, D(G(x)): 0.27
# Epoch[28], Batch[300], d_loss:1.3959, g_loss:3.2412, D(x): 0.86, D(G(x)): 0.48
# Epoch[28], Batch[600], d_loss:0.6638, g_loss:2.2576, D(x): 0.80, D(G(x)): 0.22
# Epoch[29], Batch[300], d_loss:0.7725, g_loss:2.2969, D(x): 0.79, D(G(x)): 0.29
# Epoch[29], Batch[600], d_loss:0.9343, g_loss:2.0307, D(x): 0.66, D(G(x)): 0.21
# Epoch[30], Batch[300], d_loss:0.7596, g_loss:2.2435, D(x): 0.71, D(G(x)): 0.18
# Epoch[30], Batch[600], d_loss:1.0075, g_loss:1.7471, D(x): 0.70, D(G(x)): 0.37
# Epoch[31], Batch[300], d_loss:1.0000, g_loss:1.3725, D(x): 0.66, D(G(x)): 0.32
# Epoch[31], Batch[600], d_loss:0.6558, g_loss:3.1627, D(x): 0.85, D(G(x)): 0.26
# Epoch[32], Batch[300], d_loss:0.8554, g_loss:2.4165, D(x): 0.72, D(G(x)): 0.24
# Epoch[32], Batch[600], d_loss:0.8943, g_loss:2.5194, D(x): 0.66, D(G(x)): 0.17
# Epoch[33], Batch[300], d_loss:1.0479, g_loss:1.8241, D(x): 0.71, D(G(x)): 0.36
# Epoch[33], Batch[600], d_loss:0.7534, g_loss:2.2325, D(x): 0.82, D(G(x)): 0.34
# Epoch[34], Batch[300], d_loss:0.7774, g_loss:2.2373, D(x): 0.73, D(G(x)): 0.27
# Epoch[34], Batch[600], d_loss:1.1584, g_loss:1.6639, D(x): 0.70, D(G(x)): 0.39
# Epoch[35], Batch[300], d_loss:1.0651, g_loss:1.3991, D(x): 0.70, D(G(x)): 0.39
# Epoch[35], Batch[600], d_loss:1.0519, g_loss:1.3301, D(x): 0.68, D(G(x)): 0.36
# Epoch[36], Batch[300], d_loss:1.1405, g_loss:1.6075, D(x): 0.75, D(G(x)): 0.44
# Epoch[36], Batch[600], d_loss:0.7505, g_loss:1.9445, D(x): 0.70, D(G(x)): 0.22
# Epoch[37], Batch[300], d_loss:0.9321, g_loss:1.5501, D(x): 0.71, D(G(x)): 0.32
# Epoch[37], Batch[600], d_loss:0.8764, g_loss:1.6468, D(x): 0.77, D(G(x)): 0.34
# Epoch[38], Batch[300], d_loss:1.0470, g_loss:1.6348, D(x): 0.68, D(G(x)): 0.35
# Epoch[38], Batch[600], d_loss:1.0462, g_loss:1.4356, D(x): 0.74, D(G(x)): 0.37
# Epoch[39], Batch[300], d_loss:0.9947, g_loss:1.4733, D(x): 0.68, D(G(x)): 0.32
# Epoch[39], Batch[600], d_loss:1.0688, g_loss:1.3448, D(x): 0.76, D(G(x)): 0.41
# Epoch[40], Batch[300], d_loss:1.0785, g_loss:1.3387, D(x): 0.74, D(G(x)): 0.44
# Epoch[40], Batch[600], d_loss:0.9731, g_loss:1.6078, D(x): 0.66, D(G(x)): 0.27
# Epoch[41], Batch[300], d_loss:0.9379, g_loss:1.3452, D(x): 0.65, D(G(x)): 0.28
# Epoch[41], Batch[600], d_loss:1.2167, g_loss:2.0449, D(x): 0.58, D(G(x)): 0.29
# Epoch[42], Batch[300], d_loss:1.0186, g_loss:2.1235, D(x): 0.72, D(G(x)): 0.35
# Epoch[42], Batch[600], d_loss:0.9448, g_loss:1.5437, D(x): 0.74, D(G(x)): 0.34
# Epoch[43], Batch[300], d_loss:0.9099, g_loss:1.6389, D(x): 0.72, D(G(x)): 0.34
# Epoch[43], Batch[600], d_loss:0.8892, g_loss:1.3580, D(x): 0.70, D(G(x)): 0.31
# Epoch[44], Batch[300], d_loss:1.0712, g_loss:1.7809, D(x): 0.73, D(G(x)): 0.41
# Epoch[44], Batch[600], d_loss:0.8369, g_loss:1.9302, D(x): 0.76, D(G(x)): 0.34
# Epoch[45], Batch[300], d_loss:0.8953, g_loss:2.1382, D(x): 0.65, D(G(x)): 0.24
# Epoch[45], Batch[600], d_loss:1.0217, g_loss:1.2350, D(x): 0.72, D(G(x)): 0.38
# Epoch[46], Batch[300], d_loss:0.8753, g_loss:1.4733, D(x): 0.70, D(G(x)): 0.29
# Epoch[46], Batch[600], d_loss:0.8962, g_loss:1.6015, D(x): 0.75, D(G(x)): 0.36
# Epoch[47], Batch[300], d_loss:1.0755, g_loss:1.9847, D(x): 0.63, D(G(x)): 0.27
# Epoch[47], Batch[600], d_loss:1.3001, g_loss:1.4199, D(x): 0.59, D(G(x)): 0.35
# Epoch[48], Batch[300], d_loss:1.0247, g_loss:1.4053, D(x): 0.68, D(G(x)): 0.37
# Epoch[48], Batch[600], d_loss:1.2551, g_loss:1.0095, D(x): 0.67, D(G(x)): 0.44
# Epoch[49], Batch[300], d_loss:1.0486, g_loss:1.2189, D(x): 0.69, D(G(x)): 0.39
# Epoch[49], Batch[600], d_loss:0.9452, g_loss:1.4500, D(x): 0.74, D(G(x)): 0.38
# Epoch[50], Batch[300], d_loss:0.7762, g_loss:1.6890, D(x): 0.71, D(G(x)): 0.28
# Epoch[50], Batch[600], d_loss:1.1447, g_loss:1.1879, D(x): 0.60, D(G(x)): 0.35
# Epoch[51], Batch[300], d_loss:1.0821, g_loss:1.4022, D(x): 0.68, D(G(x)): 0.37
# Epoch[51], Batch[600], d_loss:0.8945, g_loss:1.1907, D(x): 0.75, D(G(x)): 0.37
# Epoch[52], Batch[300], d_loss:1.0080, g_loss:1.7116, D(x): 0.68, D(G(x)): 0.31
# Epoch[52], Batch[600], d_loss:1.1418, g_loss:1.2601, D(x): 0.60, D(G(x)): 0.30
# Epoch[53], Batch[300], d_loss:1.0479, g_loss:1.4331, D(x): 0.64, D(G(x)): 0.31
# Epoch[53], Batch[600], d_loss:1.0696, g_loss:1.0805, D(x): 0.68, D(G(x)): 0.38
# Epoch[54], Batch[300], d_loss:1.2359, g_loss:1.3595, D(x): 0.69, D(G(x)): 0.45
# Epoch[54], Batch[600], d_loss:0.9961, g_loss:1.3750, D(x): 0.70, D(G(x)): 0.36
# Epoch[55], Batch[300], d_loss:1.0082, g_loss:1.6426, D(x): 0.62, D(G(x)): 0.24
# Epoch[55], Batch[600], d_loss:1.0451, g_loss:1.6090, D(x): 0.62, D(G(x)): 0.28
# Epoch[56], Batch[300], d_loss:1.1271, g_loss:0.9591, D(x): 0.63, D(G(x)): 0.36
# Epoch[56], Batch[600], d_loss:0.8573, g_loss:1.6125, D(x): 0.73, D(G(x)): 0.31
# Epoch[57], Batch[300], d_loss:1.0522, g_loss:1.4936, D(x): 0.67, D(G(x)): 0.36
# Epoch[57], Batch[600], d_loss:0.9611, g_loss:1.6057, D(x): 0.67, D(G(x)): 0.33
# Epoch[58], Batch[300], d_loss:1.1501, g_loss:1.1735, D(x): 0.66, D(G(x)): 0.38
# Epoch[58], Batch[600], d_loss:1.0929, g_loss:1.8346, D(x): 0.59, D(G(x)): 0.29
# Epoch[59], Batch[300], d_loss:0.8802, g_loss:1.4633, D(x): 0.78, D(G(x)): 0.38
# Epoch[59], Batch[600], d_loss:0.9544, g_loss:1.5589, D(x): 0.78, D(G(x)): 0.42
# Epoch[60], Batch[300], d_loss:1.1389, g_loss:1.2482, D(x): 0.68, D(G(x)): 0.37
# Epoch[60], Batch[600], d_loss:0.9462, g_loss:1.2589, D(x): 0.67, D(G(x)): 0.29
# Epoch[61], Batch[300], d_loss:0.8122, g_loss:1.5891, D(x): 0.69, D(G(x)): 0.25
# Epoch[61], Batch[600], d_loss:1.0245, g_loss:1.1895, D(x): 0.73, D(G(x)): 0.40
# Epoch[62], Batch[300], d_loss:0.9874, g_loss:1.5984, D(x): 0.66, D(G(x)): 0.26
# Epoch[62], Batch[600], d_loss:1.1997, g_loss:1.1508, D(x): 0.60, D(G(x)): 0.31
# Epoch[63], Batch[300], d_loss:1.0246, g_loss:1.1862, D(x): 0.72, D(G(x)): 0.36
# Epoch[63], Batch[600], d_loss:0.9288, g_loss:1.4853, D(x): 0.68, D(G(x)): 0.31
# Epoch[64], Batch[300], d_loss:1.0083, g_loss:1.7296, D(x): 0.70, D(G(x)): 0.36
# Epoch[64], Batch[600], d_loss:0.9715, g_loss:1.5826, D(x): 0.68, D(G(x)): 0.31
# Epoch[65], Batch[300], d_loss:0.7926, g_loss:1.7939, D(x): 0.75, D(G(x)): 0.30
# Epoch[65], Batch[600], d_loss:0.9053, g_loss:1.5871, D(x): 0.66, D(G(x)): 0.26
# Epoch[66], Batch[300], d_loss:0.8998, g_loss:1.1646, D(x): 0.78, D(G(x)): 0.39
# Epoch[66], Batch[600], d_loss:0.9548, g_loss:2.0386, D(x): 0.66, D(G(x)): 0.29
# Epoch[67], Batch[300], d_loss:0.9304, g_loss:1.3820, D(x): 0.73, D(G(x)): 0.33
# Epoch[67], Batch[600], d_loss:1.1945, g_loss:1.2863, D(x): 0.61, D(G(x)): 0.35
# Epoch[68], Batch[300], d_loss:0.7454, g_loss:1.8598, D(x): 0.73, D(G(x)): 0.27
# Epoch[68], Batch[600], d_loss:1.1938, g_loss:1.5579, D(x): 0.61, D(G(x)): 0.34
# Epoch[69], Batch[300], d_loss:1.0276, g_loss:1.4036, D(x): 0.67, D(G(x)): 0.34
# Epoch[69], Batch[600], d_loss:0.9711, g_loss:1.9466, D(x): 0.65, D(G(x)): 0.27
# Epoch[70], Batch[300], d_loss:1.2163, g_loss:1.4752, D(x): 0.63, D(G(x)): 0.36
# Epoch[70], Batch[600], d_loss:1.0159, g_loss:1.7337, D(x): 0.67, D(G(x)): 0.32
# Epoch[71], Batch[300], d_loss:0.9910, g_loss:1.9478, D(x): 0.60, D(G(x)): 0.22
# Epoch[71], Batch[600], d_loss:1.0238, g_loss:1.7950, D(x): 0.64, D(G(x)): 0.29
# Epoch[72], Batch[300], d_loss:0.7537, g_loss:1.5370, D(x): 0.73, D(G(x)): 0.28
# Epoch[72], Batch[600], d_loss:1.1207, g_loss:1.4879, D(x): 0.72, D(G(x)): 0.41
# Epoch[73], Batch[300], d_loss:1.0173, g_loss:1.4655, D(x): 0.75, D(G(x)): 0.42
# Epoch[73], Batch[600], d_loss:0.7474, g_loss:1.6486, D(x): 0.72, D(G(x)): 0.26
# Epoch[74], Batch[300], d_loss:0.9882, g_loss:1.5875, D(x): 0.66, D(G(x)): 0.31
# Epoch[74], Batch[600], d_loss:0.9520, g_loss:1.6091, D(x): 0.72, D(G(x)): 0.37
# Epoch[75], Batch[300], d_loss:0.8891, g_loss:2.1738, D(x): 0.67, D(G(x)): 0.27
# Epoch[75], Batch[600], d_loss:1.0418, g_loss:1.4685, D(x): 0.64, D(G(x)): 0.30
# Epoch[76], Batch[300], d_loss:1.0484, g_loss:1.6438, D(x): 0.65, D(G(x)): 0.31
# Epoch[76], Batch[600], d_loss:0.9456, g_loss:1.7762, D(x): 0.75, D(G(x)): 0.38
# Epoch[77], Batch[300], d_loss:0.9440, g_loss:1.4295, D(x): 0.65, D(G(x)): 0.27
# Epoch[77], Batch[600], d_loss:0.8283, g_loss:1.7023, D(x): 0.75, D(G(x)): 0.31
# Epoch[78], Batch[300], d_loss:0.8669, g_loss:1.8983, D(x): 0.68, D(G(x)): 0.28
# Epoch[78], Batch[600], d_loss:1.0120, g_loss:1.3666, D(x): 0.69, D(G(x)): 0.35
# Epoch[79], Batch[300], d_loss:0.9210, g_loss:1.6918, D(x): 0.75, D(G(x)): 0.33
# Epoch[79], Batch[600], d_loss:0.9660, g_loss:1.4167, D(x): 0.67, D(G(x)): 0.30
# Epoch[80], Batch[300], d_loss:0.8889, g_loss:1.4881, D(x): 0.72, D(G(x)): 0.30
# Epoch[80], Batch[600], d_loss:1.0741, g_loss:1.6584, D(x): 0.66, D(G(x)): 0.29
# Epoch[81], Batch[300], d_loss:0.7926, g_loss:1.9518, D(x): 0.75, D(G(x)): 0.28
# Epoch[81], Batch[600], d_loss:1.0089, g_loss:1.4701, D(x): 0.64, D(G(x)): 0.28
# Epoch[82], Batch[300], d_loss:0.8395, g_loss:1.5242, D(x): 0.73, D(G(x)): 0.31
# Epoch[82], Batch[600], d_loss:0.9741, g_loss:1.5140, D(x): 0.73, D(G(x)): 0.39
# Epoch[83], Batch[300], d_loss:0.9151, g_loss:1.8151, D(x): 0.67, D(G(x)): 0.28
# Epoch[83], Batch[600], d_loss:0.8320, g_loss:1.5082, D(x): 0.77, D(G(x)): 0.34
# Epoch[84], Batch[300], d_loss:0.9010, g_loss:1.5886, D(x): 0.74, D(G(x)): 0.35
# Epoch[84], Batch[600], d_loss:1.0450, g_loss:1.7670, D(x): 0.73, D(G(x)): 0.38
# Epoch[85], Batch[300], d_loss:0.8677, g_loss:1.4890, D(x): 0.75, D(G(x)): 0.33
# Epoch[85], Batch[600], d_loss:0.8791, g_loss:1.7231, D(x): 0.76, D(G(x)): 0.34
# Epoch[86], Batch[300], d_loss:0.9753, g_loss:1.0076, D(x): 0.74, D(G(x)): 0.39
# Epoch[86], Batch[600], d_loss:1.0810, g_loss:1.7187, D(x): 0.67, D(G(x)): 0.32
# Epoch[87], Batch[300], d_loss:0.8474, g_loss:1.3767, D(x): 0.75, D(G(x)): 0.31
# Epoch[87], Batch[600], d_loss:0.8998, g_loss:1.3802, D(x): 0.65, D(G(x)): 0.26
# Epoch[88], Batch[300], d_loss:0.9119, g_loss:1.3917, D(x): 0.69, D(G(x)): 0.30
# Epoch[88], Batch[600], d_loss:0.8410, g_loss:1.5140, D(x): 0.76, D(G(x)): 0.33
# Epoch[89], Batch[300], d_loss:0.8917, g_loss:1.3960, D(x): 0.69, D(G(x)): 0.31
# Epoch[89], Batch[600], d_loss:0.9113, g_loss:1.8021, D(x): 0.79, D(G(x)): 0.38
# Epoch[90], Batch[300], d_loss:1.0947, g_loss:1.8196, D(x): 0.61, D(G(x)): 0.29
# Epoch[90], Batch[600], d_loss:0.9310, g_loss:1.9598, D(x): 0.73, D(G(x)): 0.35
# Epoch[91], Batch[300], d_loss:0.9097, g_loss:1.6467, D(x): 0.66, D(G(x)): 0.29
# Epoch[91], Batch[600], d_loss:1.0092, g_loss:1.7714, D(x): 0.66, D(G(x)): 0.31
# Epoch[92], Batch[300], d_loss:1.0676, g_loss:1.3651, D(x): 0.67, D(G(x)): 0.35
# Epoch[92], Batch[600], d_loss:0.9999, g_loss:1.4818, D(x): 0.69, D(G(x)): 0.33
# Epoch[93], Batch[300], d_loss:0.9655, g_loss:1.4958, D(x): 0.73, D(G(x)): 0.36
# Epoch[93], Batch[600], d_loss:0.9294, g_loss:1.7074, D(x): 0.66, D(G(x)): 0.30
# Epoch[94], Batch[300], d_loss:1.0503, g_loss:1.6283, D(x): 0.69, D(G(x)): 0.36
# Epoch[94], Batch[600], d_loss:0.8460, g_loss:1.6124, D(x): 0.73, D(G(x)): 0.31
# Epoch[95], Batch[300], d_loss:0.8756, g_loss:1.3821, D(x): 0.76, D(G(x)): 0.35
# Epoch[95], Batch[600], d_loss:0.8986, g_loss:1.3658, D(x): 0.68, D(G(x)): 0.28
# Epoch[96], Batch[300], d_loss:0.8801, g_loss:1.6463, D(x): 0.63, D(G(x)): 0.22
# Epoch[96], Batch[600], d_loss:1.0345, g_loss:1.6553, D(x): 0.70, D(G(x)): 0.34
# Epoch[97], Batch[300], d_loss:1.0519, g_loss:1.4897, D(x): 0.68, D(G(x)): 0.35
# Epoch[97], Batch[600], d_loss:0.9943, g_loss:1.1164, D(x): 0.70, D(G(x)): 0.35
# Epoch[98], Batch[300], d_loss:1.0110, g_loss:1.8666, D(x): 0.64, D(G(x)): 0.27
# Epoch[98], Batch[600], d_loss:1.1077, g_loss:1.3488, D(x): 0.67, D(G(x)): 0.35
# Epoch[99], Batch[300], d_loss:0.9857, g_loss:1.4642, D(x): 0.74, D(G(x)): 0.38
# Epoch[99], Batch[600], d_loss:0.8951, g_loss:1.4627, D(x): 0.70, D(G(x)): 0.31
# Epoch[100], Batch[300], d_loss:0.9908, g_loss:1.5950, D(x): 0.64, D(G(x)): 0.28
# Epoch[100], Batch[600], d_loss:1.1030, g_loss:1.2240, D(x): 0.64, D(G(x)): 0.33
# Epoch[101], Batch[300], d_loss:0.9707, g_loss:1.6887, D(x): 0.66, D(G(x)): 0.31
# Epoch[101], Batch[600], d_loss:0.8721, g_loss:1.6151, D(x): 0.71, D(G(x)): 0.30
# Epoch[102], Batch[300], d_loss:0.8889, g_loss:1.6056, D(x): 0.68, D(G(x)): 0.27
# Epoch[102], Batch[600], d_loss:0.8835, g_loss:1.6593, D(x): 0.73, D(G(x)): 0.33
# Epoch[103], Batch[300], d_loss:1.0359, g_loss:1.7234, D(x): 0.74, D(G(x)): 0.39
# Epoch[103], Batch[600], d_loss:0.9852, g_loss:1.7128, D(x): 0.60, D(G(x)): 0.23
# Epoch[104], Batch[300], d_loss:0.8511, g_loss:1.2853, D(x): 0.77, D(G(x)): 0.35
# Epoch[104], Batch[600], d_loss:1.0210, g_loss:1.1750, D(x): 0.73, D(G(x)): 0.38
# Epoch[105], Batch[300], d_loss:0.9433, g_loss:2.1292, D(x): 0.63, D(G(x)): 0.22
# Epoch[105], Batch[600], d_loss:0.9005, g_loss:1.5633, D(x): 0.75, D(G(x)): 0.36
# Epoch[106], Batch[300], d_loss:0.9861, g_loss:1.6293, D(x): 0.64, D(G(x)): 0.26
# Epoch[106], Batch[600], d_loss:0.8989, g_loss:1.5939, D(x): 0.66, D(G(x)): 0.27
# Epoch[107], Batch[300], d_loss:0.9385, g_loss:1.5365, D(x): 0.71, D(G(x)): 0.31
# Epoch[107], Batch[600], d_loss:0.9070, g_loss:1.4836, D(x): 0.74, D(G(x)): 0.35
# Epoch[108], Batch[300], d_loss:0.9664, g_loss:2.0036, D(x): 0.66, D(G(x)): 0.29
# Epoch[108], Batch[600], d_loss:0.9410, g_loss:1.4374, D(x): 0.70, D(G(x)): 0.32
# Epoch[109], Batch[300], d_loss:1.0118, g_loss:1.5460, D(x): 0.61, D(G(x)): 0.27
# Epoch[109], Batch[600], d_loss:0.9350, g_loss:1.8898, D(x): 0.65, D(G(x)): 0.25
# Epoch[110], Batch[300], d_loss:0.8778, g_loss:1.7434, D(x): 0.68, D(G(x)): 0.26
# Epoch[110], Batch[600], d_loss:1.0694, g_loss:2.1103, D(x): 0.59, D(G(x)): 0.23
# Epoch[111], Batch[300], d_loss:1.0475, g_loss:1.6998, D(x): 0.68, D(G(x)): 0.37
# Epoch[111], Batch[600], d_loss:0.9243, g_loss:1.5112, D(x): 0.67, D(G(x)): 0.30
# Epoch[112], Batch[300], d_loss:1.0684, g_loss:1.8787, D(x): 0.60, D(G(x)): 0.26
# Epoch[112], Batch[600], d_loss:0.9843, g_loss:1.7906, D(x): 0.77, D(G(x)): 0.36
# Epoch[113], Batch[300], d_loss:1.0916, g_loss:1.3431, D(x): 0.65, D(G(x)): 0.34
# Epoch[113], Batch[600], d_loss:0.9778, g_loss:1.6338, D(x): 0.72, D(G(x)): 0.37
# Epoch[114], Batch[300], d_loss:1.1113, g_loss:1.8903, D(x): 0.59, D(G(x)): 0.26
# Epoch[114], Batch[600], d_loss:1.0759, g_loss:2.0981, D(x): 0.62, D(G(x)): 0.27
